# %% [markdown]
# ___
# # Ciência dos Dados - Projeto 3: Filmes#
# ___
#
# ### _Gabriela Caruso e Mariana Abrantes - 2C_ ###
# ___

# %% [markdown]
# ## Objetivo ##
#
# Desenvolver um programa que cria uma playlist de filmes similares a um outro usado como parâmetro.
#
# ___

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
# %reset -f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import math
import seaborn as sns
from scipy.stats import norm
from mpl_toolkits.mplot3d import Axes3D
from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

np.random.seed(42)

# %% [markdown]
# ## Lendo as tabelas

# %%
#df = pd.read_csv('https://query.data.world/s/dgju3rv2knocz2ost6qyly7vwyekcv')
#writer = pd.ExcelWriter('Projeto3_CD.xlsx')
#df.to_excel(writer,'data')
#writer.save()

# %%
df = pd.read_excel('Projeto3_CD.xlsx')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Eliminando colunas

# %%
dado = df.drop(labels=None, axis=0, index=None, columns='movie_imdb_link', level=None, inplace=False, errors='raise')
dado2 = dado.drop(labels=None, axis=0, index=None, columns='aspect_ratio', level=None, inplace=False, errors='raise')
dado3 = dado2.drop(labels=None, axis=0, index=None, columns='language', level=None, inplace=False, errors='raise')
data = dado3.dropna(axis = 0, how = "any", thresh = None, subset = None, inplace = False)
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#           ...          facenumber_in_poster  \
# 0         ...                           0.0
# 1         ...                           0.0
# 2         ...                           1.0
# 3         ...                           0.0
# 5         ...                           1.0
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 5  alien|american civil war|male nipple|mars|prin...                 738.0
#
#    country content_rating       budget title_year  actor_2_facebook_likes  \
# 0      USA          PG-13  237000000.0     2009.0                   936.0
# 1      USA          PG-13  300000000.0     2007.0                  5000.0
# 2       UK          PG-13  245000000.0     2015.0                   393.0
# 3      USA          PG-13  250000000.0     2012.0                 23000.0
# 5      USA          PG-13  263700000.0     2012.0                   632.0
#
#   imdb_score movie_facebook_likes
# 0        7.9                33000
# 1        7.1                    0
# 2        6.8                85000
# 3        8.5               164000
# 5        6.6                24000
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Print das colunas

# %%
a = list(data)
print(len(a))
a
# Out:
# 25
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'num_user_for_reviews',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'movie_facebook_likes']

# %% [markdown]
# ## Alterando os dados escritos por numéricos

# %%
lista_nova = []
for color in data["color"]:
    if color == " Black and White":
        lista_nova.append(1)
    elif color == "Color":
        lista_nova.append(0)
    else:
        lista_nova.append(color)
        
data["color"] = lista_nova
data.head()
# Out:
# /Users/gabrielacaruso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    color      director_name  num_critic_for_reviews  duration  \
# 0      0      James Cameron                   723.0     178.0
# 1      0     Gore Verbinski                   302.0     169.0
# 2      0         Sam Mendes                   602.0     148.0
# 3      0  Christopher Nolan                   813.0     164.0
# 5      0     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#           ...          facenumber_in_poster  \
# 0         ...                           0.0
# 1         ...                           0.0
# 2         ...                           1.0
# 3         ...                           0.0
# 5         ...                           1.0
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 5  alien|american civil war|male nipple|mars|prin...                 738.0
#
#    country content_rating       budget title_year  actor_2_facebook_likes  \
# 0      USA          PG-13  237000000.0     2009.0                   936.0
# 1      USA          PG-13  300000000.0     2007.0                  5000.0
# 2       UK          PG-13  245000000.0     2015.0                   393.0
# 3      USA          PG-13  250000000.0     2012.0                 23000.0
# 5      USA          PG-13  263700000.0     2012.0                   632.0
#
#   imdb_score movie_facebook_likes
# 0        7.9                33000
# 1        7.1                    0
# 2        6.8                85000
# 3        8.5               164000
# 5        6.6                24000
#
# [5 rows x 25 columns]

# %%
def numerar(dataframe, coluna):
    # Criando a lista de nomes únicos:
    unico = []
    for classe in dataframe[coluna]:
        if classe not in unico:
            unico.append(classe)
            
    # Criando a lista de nomes alterados para números:
    reclassificado = []        
    for item in dataframe[coluna]:
        reclassificado.append(unico.index(item))
    
    # Substituindo a coluna toda do DataFrame:
    dataframe[coluna] = reclassificado
    
    # Retornando o novo DataFrame:
    return dataframe

# %%
numerar(data, "actor_2_name")
numerar(data, "director_name")
numerar(data, "actor_1_name")
numerar(data, "movie_title")
numerar(data, "genres")
numerar(data, "actor_3_name")
numerar(data, "plot_keywords")
numerar(data, "country")
numerar(data, "content_rating")
data.head()
# Out:
# /Users/gabrielacaruso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    color  director_name  num_critic_for_reviews  duration  \
# 0      0              0                   723.0     178.0
# 1      0              1                   302.0     169.0
# 2      0              2                   602.0     148.0
# 3      0              3                   813.0     164.0
# 5      0              4                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                      0.0                   855.0             0
# 1                    563.0                  1000.0             1
# 2                      0.0                   161.0             2
# 3                  22000.0                 23000.0             3
# 5                    475.0                   530.0             4
#
#    actor_1_facebook_likes        gross  genres          ...           \
# 0                  1000.0  760505847.0       0          ...
# 1                 40000.0  309404152.0       1          ...
# 2                 11000.0  200074175.0       2          ...
# 3                 27000.0  448130642.0       3          ...
# 5                   640.0   73058679.0       4          ...
#
#    facenumber_in_poster  plot_keywords  num_user_for_reviews  country  \
# 0                   0.0              0                3054.0        0
# 1                   0.0              1                1238.0        0
# 2                   1.0              2                 994.0        1
# 3                   0.0              3                2701.0        0
# 5                   1.0              4                 738.0        0
#
#    content_rating       budget  title_year  actor_2_facebook_likes  \
# 0               0  237000000.0      2009.0                   936.0
# 1               0  300000000.0      2007.0                  5000.0
# 2               0  245000000.0      2015.0                   393.0
# 3               0  250000000.0      2012.0                 23000.0
# 5               0  263700000.0      2012.0                   632.0
#
#    imdb_score  movie_facebook_likes
# 0         7.9                 33000
# 1         7.1                     0
# 2         6.8                 85000
# 3         8.5                164000
# 5         6.6                 24000
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Fazendo a correlação

# %%
data.corr()
# Out:
#                               color  director_name  num_critic_for_reviews  \
# color                      1.000000       0.024277                0.000433
# director_name              0.024277       1.000000               -0.339507
# num_critic_for_reviews     0.000433      -0.339507                1.000000
# duration                   0.048309      -0.281636                0.234857
# director_facebook_likes    0.058906      -0.171929                0.177149
# actor_3_facebook_likes    -0.021425      -0.181164                0.254392
# actor_2_name               0.062496       0.624622               -0.312060
# actor_1_facebook_likes    -0.025192      -0.166866                0.167554
# gross                     -0.042298      -0.465605                0.468543
# genres                     0.067819       0.319629               -0.189853
# actor_1_name               0.069049       0.564072               -0.293632
# movie_title                0.058676       0.764070               -0.372643
# num_voted_users            0.035500      -0.386766                0.595359
# cast_total_facebook_likes -0.029392      -0.218665                0.238548
# actor_3_name               0.070724       0.651531               -0.306475
# facenumber_in_poster       0.004143       0.007803               -0.033933
# plot_keywords              0.058602       0.764079               -0.371955
# num_user_for_reviews       0.070065      -0.351681                0.567318
# country                    0.011345       0.168772               -0.017015
# content_rating             0.097749       0.284056               -0.065610
# budget                    -0.014921      -0.097264                0.106323
# title_year                -0.158317      -0.087422                0.411971
# actor_2_facebook_likes    -0.020326      -0.210885                0.255444
# imdb_score                 0.119175      -0.112170                0.346468
# movie_facebook_likes      -0.024289      -0.203569                0.704254
#
#                            duration  director_facebook_likes  \
# color                      0.048309                 0.058906
# director_name             -0.281636                -0.171929
# num_critic_for_reviews     0.234857                 0.177149
# duration                   1.000000                 0.181995
# director_facebook_likes    0.181995                 1.000000
# actor_3_facebook_likes     0.127574                 0.118142
# actor_2_name              -0.225801                -0.115055
# actor_1_facebook_likes     0.085524                 0.089980
# gross                      0.249918                 0.140088
# genres                    -0.099500                -0.071437
# actor_1_name              -0.207049                -0.111630
# movie_title               -0.288016                -0.111941
# num_voted_users            0.342898                 0.300820
# cast_total_facebook_likes  0.122384                 0.119109
# actor_3_name              -0.253215                -0.102543
# facenumber_in_poster       0.027535                -0.047847
# plot_keywords             -0.288015                -0.111973
# num_user_for_reviews       0.355159                 0.218644
# country                    0.044755                -0.043668
# content_rating            -0.016686                -0.015701
# budget                     0.069254                 0.018739
# title_year                -0.130284                -0.045337
# actor_2_facebook_likes     0.130587                 0.116837
# imdb_score                 0.364175                 0.191590
# movie_facebook_likes       0.217478                 0.162913
#
#                            actor_3_facebook_likes  actor_2_name  \
# color                                   -0.021425      0.062496
# director_name                           -0.181164      0.624622
# num_critic_for_reviews                   0.254392     -0.312060
# duration                                 0.127574     -0.225801
# director_facebook_likes                  0.118142     -0.115055
# actor_3_facebook_likes                   1.000000     -0.248532
# actor_2_name                            -0.248532      1.000000
# actor_1_facebook_likes                   0.252132     -0.240987
# gross                                    0.301203     -0.405730
# genres                                  -0.131029      0.334501
# actor_1_name                            -0.222691      0.676205
# movie_title                             -0.216884      0.744787
# num_voted_users                          0.269097     -0.309173
# cast_total_facebook_likes                0.489179     -0.318910
# actor_3_name                            -0.234624      0.693557
# facenumber_in_poster                     0.105944     -0.030635
# plot_keywords                           -0.217025      0.745273
# num_user_for_reviews                     0.206994     -0.282693
# country                                 -0.062927      0.200956
# content_rating                          -0.105952      0.294612
# budget                                   0.040583     -0.087494
# title_year                               0.116211     -0.210263
# actor_2_facebook_likes                   0.553807     -0.322557
# imdb_score                               0.065472     -0.023529
# movie_facebook_likes                     0.272473     -0.201464
#
#                            actor_1_facebook_likes     gross    genres  \
# color                                   -0.025192 -0.042298  0.067819
# director_name                           -0.166866 -0.465605  0.319629
# num_critic_for_reviews                   0.167554  0.468543 -0.189853
# duration                                 0.085524  0.249918 -0.099500
# director_facebook_likes                  0.089980  0.140088 -0.071437
# actor_3_facebook_likes                   0.252132  0.301203 -0.131029
# actor_2_name                            -0.240987 -0.405730  0.334501
# actor_1_facebook_likes                   1.000000  0.145277 -0.126090
# gross                                    0.145277  1.000000 -0.285279
# genres                                  -0.126090 -0.285279  1.000000
# actor_1_name                            -0.314002 -0.339816  0.319621
# movie_title                             -0.173821 -0.534915  0.395372
# num_voted_users                          0.180355  0.627061 -0.228415
# cast_total_facebook_likes                0.944981  0.237030 -0.156944
# actor_3_name                            -0.191676 -0.439656  0.369038
# facenumber_in_poster                     0.061878 -0.030429 -0.062340
# plot_keywords                           -0.174015 -0.535177  0.396298
# num_user_for_reviews                     0.123186  0.547510 -0.189125
# country                                 -0.067618 -0.144251  0.056531
# content_rating                          -0.067127 -0.260617  0.177154
# budget                                   0.016923  0.100781 -0.028989
# title_year                               0.095699  0.052195 -0.149954
# actor_2_facebook_likes                   0.390429  0.254231 -0.128304
# imdb_score                               0.092918  0.214421 -0.007447
# movie_facebook_likes                     0.130939  0.368940 -0.126498
#
#                                    ...           facenumber_in_poster  \
# color                              ...                       0.004143
# director_name                      ...                       0.007803
# num_critic_for_reviews             ...                      -0.033933
# duration                           ...                       0.027535
# director_facebook_likes            ...                      -0.047847
# actor_3_facebook_likes             ...                       0.105944
# actor_2_name                       ...                      -0.030635
# actor_1_facebook_likes             ...                       0.061878
# gross                              ...                      -0.030429
# genres                             ...                      -0.062340
# actor_1_name                       ...                      -0.043352
# movie_title                        ...                       0.008551
# num_voted_users                    ...                      -0.032170
# cast_total_facebook_likes          ...                       0.084258
# actor_3_name                       ...                      -0.031402
# facenumber_in_poster               ...                       1.000000
# plot_keywords                      ...                       0.008261
# num_user_for_reviews               ...                      -0.080464
# country                            ...                      -0.026407
# content_rating                     ...                      -0.042177
# budget                             ...                      -0.021498
# title_year                         ...                       0.071774
# actor_2_facebook_likes             ...                       0.072402
# imdb_score                         ...                      -0.064402
# movie_facebook_likes               ...                       0.016967
#
#                            plot_keywords  num_user_for_reviews   country  \
# color                           0.058602              0.070065  0.011345
# director_name                   0.764079             -0.351681  0.168772
# num_critic_for_reviews         -0.371955              0.567318 -0.017015
# duration                       -0.288015              0.355159  0.044755
# director_facebook_likes        -0.111973              0.218644 -0.043668
# actor_3_facebook_likes         -0.217025              0.206994 -0.062927
# actor_2_name                    0.745273             -0.282693  0.200956
# actor_1_facebook_likes         -0.174015              0.123186 -0.067618
# gross                          -0.535177              0.547510 -0.144251
# genres                          0.396298             -0.189125  0.056531
# actor_1_name                    0.632580             -0.247558  0.227504
# movie_title                     0.999669             -0.330954  0.173167
# num_voted_users                -0.337804              0.780247 -0.063042
# cast_total_facebook_likes      -0.235784              0.180333 -0.087072
# actor_3_name                    0.805955             -0.284218  0.191154
# facenumber_in_poster            0.008261             -0.080464 -0.026407
# plot_keywords                   1.000000             -0.330983  0.174318
# num_user_for_reviews           -0.330983              1.000000 -0.059141
# country                         0.174318             -0.059141  1.000000
# content_rating                  0.372505             -0.071128  0.149231
# budget                         -0.129161              0.071807  0.069954
# title_year                     -0.210824              0.016485  0.041655
# actor_2_facebook_likes         -0.229186              0.188866 -0.071406
# imdb_score                      0.036786              0.323617  0.120141
# movie_facebook_likes           -0.227780              0.372251 -0.010790
#
#                            content_rating    budget  title_year  \
# color                            0.097749 -0.014921   -0.158317
# director_name                    0.284056 -0.097264   -0.087422
# num_critic_for_reviews          -0.065610  0.106323    0.411971
# duration                        -0.016686  0.069254   -0.130284
# director_facebook_likes         -0.015701  0.018739   -0.045337
# actor_3_facebook_likes          -0.105952  0.040583    0.116211
# actor_2_name                     0.294612 -0.087494   -0.210263
# actor_1_facebook_likes          -0.067127  0.016923    0.095699
# gross                           -0.260617  0.100781    0.052195
# genres                           0.177154 -0.028989   -0.149954
# actor_1_name                     0.260712 -0.048656   -0.177069
# movie_title                      0.372158 -0.151793   -0.210950
# num_voted_users                 -0.061979  0.067271    0.020961
# cast_total_facebook_likes       -0.091820  0.029335    0.126140
# actor_3_name                     0.306367 -0.095598   -0.174281
# facenumber_in_poster            -0.042177 -0.021498    0.071774
# plot_keywords                    0.372505 -0.129161   -0.210824
# num_user_for_reviews            -0.071128  0.071807    0.016485
# country                          0.149231  0.069954    0.041655
# content_rating                   1.000000 -0.047446   -0.219546
# budget                          -0.047446  1.000000    0.046273
# title_year                      -0.219546  0.046273    1.000000
# actor_2_facebook_likes          -0.067354  0.036335    0.120975
# imdb_score                       0.174201  0.029352   -0.134204
# movie_facebook_likes            -0.072027  0.053308    0.304099
#
#                            actor_2_facebook_likes  imdb_score  \
# color                                   -0.020326    0.119175
# director_name                           -0.210885   -0.112170
# num_critic_for_reviews                   0.255444    0.346468
# duration                                 0.130587    0.364175
# director_facebook_likes                  0.116837    0.191590
# actor_3_facebook_likes                   0.553807    0.065472
# actor_2_name                            -0.322557   -0.023529
# actor_1_facebook_likes                   0.390429    0.092918
# gross                                    0.254231    0.214421
# genres                                  -0.128304   -0.007447
# actor_1_name                            -0.285409   -0.050539
# movie_title                             -0.229045    0.036552
# num_voted_users                          0.246297    0.479617
# cast_total_facebook_likes                0.642095    0.106161
# actor_3_name                            -0.247625    0.017903
# facenumber_in_poster                     0.072402   -0.064402
# plot_keywords                           -0.229186    0.036786
# num_user_for_reviews                     0.188866    0.323617
# country                                 -0.071406    0.120141
# content_rating                          -0.067354    0.174201
# budget                                   0.036335    0.029352
# title_year                               0.120975   -0.134204
# actor_2_facebook_likes                   1.000000    0.102389
# imdb_score                               0.102389    1.000000
# movie_facebook_likes                     0.233520    0.279648
#
#                            movie_facebook_likes
# color                                 -0.024289
# director_name                         -0.203569
# num_critic_for_reviews                 0.704254
# duration                               0.217478
# director_facebook_likes                0.162913
# actor_3_facebook_likes                 0.272473
# actor_2_name                          -0.201464
# actor_1_facebook_likes                 0.130939
# gross                                  0.368940
# genres                                -0.126498
# actor_1_name                          -0.185643
# movie_title                           -0.227752
# num_voted_users                        0.518850
# cast_total_facebook_likes              0.206352
# actor_3_name                          -0.190596
# facenumber_in_poster                   0.016967
# plot_keywords                         -0.227780
# num_user_for_reviews                   0.372251
# country                               -0.010790
# content_rating                        -0.072027
# budget                                 0.053308
# title_year                             0.304099
# actor_2_facebook_likes                 0.233520
# imdb_score                             0.279648
# movie_facebook_likes                   1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(data.corr(), linewidth=2)

# %%
print(len(data["budget"]))
print(len(data["movie_facebook_likes"]))
print(len(data["imdb_score"]))
print(len(data["gross"]))
# Out:
# 3806
# 3806
# 3806
# 3806

# %%
data2 = data[["budget", "movie_facebook_likes", "imdb_score", "gross" ]]
data2.head()
# Out:
#         budget  movie_facebook_likes  imdb_score        gross
# 0  237000000.0                 33000         7.9  760505847.0
# 1  300000000.0                     0         7.1  309404152.0
# 2  245000000.0                 85000         6.8  200074175.0
# 3  250000000.0                164000         8.5  448130642.0
# 5  263700000.0                 24000         6.6   73058679.0

# %%
sns.set(style="ticks")
sns.pairplot(data2);

# %%
#k_means = cluster.KMeans(n_clusters=3)
#k_means.fit(data)

# %%
#plt3d = plt.figure().gca(projection="3d")
#plt3d.scatter(data.color, data.director_name, data.num_critic_for_reviews)
